# %%
from data.matrix import get_split 
from util.util import get_data_csv

# %%
get_data_csv('catalogue/palaces_preprocessed.csv')
# Out:
# INFO:root:Extracting DataFrame
# INFO:root:DataFrame is extracted
#              id                                Особенности коврика  \
# 0     110072580                      мягкий теплый гипоаллергенный
# 1     110072682                      мягкий теплый гипоаллергенный
# 2      78438855  влаговпитывающий влагоотталкивающий грязезащитный
# 3     147208080  антистатичный гипоаллергенный натуральный мате...
# 4      63880570  придверный для декора комнаты кухни кабинета б...
# ...         ...                                                ...
# 4819  150141381                   антистатичный легкий уход теплый
# 4820   83851151                                  абстрактный принт
# 4821   83846230                                  абстрактный принт
# 4822  151385984        практичный износоустойчивый цветоустойчивый
# 4823   72074177           антискользящий мягкий оригинальная форма
#
#       Размер комнатного коврика  \
# 0                      0.999953
# ...

# %%
get_data_csv('catalogue/pred.csv')
# Out:
# INFO:root:Extracting DataFrame
# INFO:root:DataFrame is extracted
#           id            Особенности коврика  Размер комнатного коврика  \
# 0  110072580  мягкий теплый гипоаллергенный                   0.999953
#
#          Комната назначения Страна производства  \
# 0  спальня гостиная детская              россия
#
#                    Назначение коврика                              Повод  \
# 0  интерьерный комнатный прикроватный  день рождения новоселье новый год
#
#      Назначение подарка  Ширина предмета                Форма коврика  \
# 0  любимой маме бабушке            0.625  прямоугольная прямоугольник
#
#       Способ производства коврика Материал изделия Основа коврика  \
# 0  машинный машинное производство     полиамид 100         войлок
#
#           Рисунок  Длина упаковки  Высота упаковки  Ширина упаковки  \
# 0  геометрический        0.369565        -0.416667        -0.153846
#
#                                             Описание  \
# ...

# %%
features, pred, target  = get_split('catalogue/palaces_preprocessed.csv','catalogue/pred.csv','dicsounted Price')
# Out:
# INFO:root:Extracting DataFrame
# INFO:root:DataFrame is extracted
# INFO:root:Extracting DataFrame
# INFO:root:DataFrame is extracted
# INFO:root:is id numeric,categorical or target column?
# Index(['id', 'Особенности коврика', 'Размер комнатного коврика',
#        'Комната назначения', 'Страна производства', 'Назначение коврика',
#        'Повод', 'Назначение подарка', 'Ширина предмета', 'Форма коврика',
#        'Способ производства коврика', 'Материал изделия', 'Основа коврика',
#        'Рисунок', 'Длина упаковки', 'Высота упаковки', 'Ширина упаковки',
#        'Описание', 'name', 'brand'],
#       dtype='object')
# INFO:root:is Особенности коврика numeric,categorical or target column?
# INFO:root:is Размер комнатного коврика numeric,categorical or target column?
# INFO:root:is Комната назначения numeric,categorical or target column?
# INFO:root:is Страна производства numeric,categorical or target column?
# INFO:root:is Назначение коврика numeric,categorical or target column?
# ...
